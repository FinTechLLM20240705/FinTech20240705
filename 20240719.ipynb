# %%
#!pip install langchain_community
#!pip install chromadb
#!pip install openai

# %%
from langchain_community.chat_models import ChatOpenAI
from langchain.chains import ConversationalRetrievalChain
import os
import json
from langchain.embeddings import OpenAIEmbeddings
from langchain.vectorstores import Chroma
from langchain_community.document_loaders import JSONLoader
import chromadb
from chromadb.config import Settings
from chromadb.utils import embedding_functions
import time
import pandas as pd

# %%
# 设置OpenAI API密钥
f = open("./openai_key.txt", 'r')
openai_key=f.read()
f.close()
os.environ["OPENAI_API_KEY"] = openai_key

# 加载CSV文件
csv_file_path = './ptt_stock_articles.csv'
comments_file_path = './ptt_stock_comments.csv'

df = pd.read_csv(csv_file_path)
df_comments = pd.read_csv(comments_file_path)

# 将CSV文件转换为JSONL文件
jsonl_file_path = 'combined_ptt_stock_documents.jsonl'
df.to_json(jsonl_file_path, orient='records', lines=True, force_ascii=False)

# %%
df
# Out:
#                                                   URL  \
# 0   https://www.ptt.cc/bbs/Stock/M.1721364282.A.AC...
# 1   https://www.ptt.cc/bbs/Stock/M.1721364406.A.4F...
# 2   https://www.ptt.cc/bbs/Stock/M.1721365467.A.4E...
# 3   https://www.ptt.cc/bbs/Stock/M.1721365814.A.7A...
# 4   https://www.ptt.cc/bbs/Stock/M.1719872231.A.9B...
# 5   https://www.ptt.cc/bbs/Stock/M.1721349002.A.3F...
# 6   https://www.ptt.cc/bbs/Stock/M.1721356359.A.52...
# 7   https://www.ptt.cc/bbs/Stock/M.1721356684.A.29...
# 8   https://www.ptt.cc/bbs/Stock/M.1721357100.A.14...
# 9   https://www.ptt.cc/bbs/Stock/M.1721357144.A.38...
# 10  https://www.ptt.cc/bbs/Stock/M.1721357505.A.22...
# 11  https://www.ptt.cc/bbs/Stock/M.1721358283.A.C2...
# 12  https://www.ptt.cc/bbs/Stock/M.1721358692.A.95...
# 13  https://www.ptt.cc/bbs/Stock/M.1721358762.A.6E...
# 14  https://www.ptt.cc/bbs/Stock/M.1721358946.A.0D...
# 15  https://www.ptt.cc/bbs/Stock/M.1721359614.A.9F...
# 16  https://www.ptt.cc/bbs/Stock/M.1721359639.A.27...
# 17  https://www.ptt.cc/bbs/Stock/M.1721360094.A.2B...
# 18  https://www.ptt.cc/bbs/Stock/M.1721360279.A.67...
# 19  https://www.ptt.cc/bbs/Stock/M.1721360596.A.DB...
# 20  https://www.ptt.cc/bbs/Stock/M.1721360598.A.2C...
# 21  https://www.ptt.cc/bbs/Stock/M.1721360784.A.E7...
# 22  https://www.ptt.cc/bbs/Stock/M.1721361110.A.28...
# 23  https://www.ptt.cc/bbs/Stock/M.1721363208.A.41...
# 24  https://www.ptt.cc/bbs/Stock/M.1721363301.A.A3...
# 25  https://www.ptt.cc/bbs/Stock/M.1721363445.A.44...
#
#                               Title  \
# 0       [新聞] 由 4,300 公里海底電纜從澳洲輸電新加坡
# 1         [新聞] 不受川普保護費說影響 中經院1理由上修台
# 2            [情報] 2429 銘旺科 申購抽籤日程資訊
# 3                [心得] 台積電是咒術迴戰裡面的真人
# 4   [公告] 股票板板規 v4.6 (2024/07/02 修正)
# 5              [閒聊] 2024/07/19 盤中閒聊
# 6                     [請益] 請問華航怎麼了？
# 7                  [標的] 6869 雲豹能源 空
# 8      Re: [情報] 6405悅城處分台積電普通股股票之公告
# 9           [新聞] 高盛：人工智慧投資正在泡沫化、短期內
# 10              [情報] 哇操，台幣貶破32.7了喔？
# 11              [新聞] 紡纖廠有志一同 大舉投資綠能
# 12            Re:  [請益]  雲豹到底憑甚麼漲停？
# 13                   [請益] 請問長榮航怎麼了？
# 14                   [請益] 955入場的時機點
# 15                      [標的] 旺矽還是豐藝
# 16           [請益] 如果川普現在買台積電，算內線交易嗎
# 17          Re: [標的] 00679B~元大美債20年
# 18      Re: [新聞] 高盛：人工智慧投資正在泡沫化、短期內
# 19                [請益] 台灣有那些汽油車概念股?
# 20               [標的] 3060 銘異 先蹲後跳多
# 21    [新聞] 卡位AI有優勢 科技股一片殺聲Palantir逆
# 22         [新聞] 川普口水有多毒？曝光台積電最大弱點 命
# 23             [標的]1524耿鼎_川普汽車工業概念股
# 24         Re: [標的] 6820.tw連訊(興櫃) 多
# 25             Re: [請益]  雲豹到底憑甚麼漲停？
#
#                                               Content
# 0   原文標題：\n\n由 4,300 公里海底電纜從澳洲輸電新加坡，計畫獲重要進展\n\n原文連...
# 1   原文標題：不受川普保護費說影響 中經院1理由上修台灣經濟成長率\n\n\n原文連結：\n\n...
# 2   1. 標題：2429 銘旺科 申購抽籤日程資訊\n\n2. 來源：TWSE 公開申購公告-抽...
# 3   台積電 --> 真人\n\n美國 --> 夏油傑\n\n美國根本就是牢牢的掌握台積電，\n等...
# 4   1. 發文規範與分類總則 2. 股票板板規執法範圍 --------------------...
# 5   ==============113/07/19台股資訊重點整理，供股民做投資參考======...
# 6   一堆利好跟利多\nMSCI空運物流指數也持續在上升\n華航可以跌倒跌成這樣\n這波根本完全都...
# 7   標的：6869 雲豹能源\n\n\n分類：空\n\n\n分析/正文：\n\n看到今天這根漲停...
# 8   中環在幾天前高割離席處分台積電股票，反觀悅城破千才要進來，上次也是套在最高點，之後血虧出場，...
# 9   高盛：人工智慧投資正在泡沫化、短期內還不會破裂\n\n\n\nMoneyDJ新聞 2024-...
# 10  今天早盤台幣貶破32.7了，帶量突破這三年來的高點，現在看這個型態越看越像三角收斂突\n破 ...
# 11  原文標題：紡纖廠有志一同 大舉投資綠能\n\n\n原文連結：\n\n發布時間：2024.07...
# 12  一支股票的興衰過程跟市場看法大概是這樣吧\n\n有題材，沒營收，初升期\n：炒作，爛股票，這...
# 13  一堆利多和營收棒棒der\nMSCI空運物流指數也持續在上升\n長榮航可以跌倒跌成這樣\n這...
# 14  大家好，小弟最近有個投資上的困惑想請教大家\n前兩個禮拜949上市時就一直很想買\n但最近看...
# 15  剛加入股市不久\n運氣好有買到旺矽跟豐藝\n最近台股下跌想要先出一隻\n不知道各位高手 有沒...
# 16  基於各種原因\n最近川普的發言似乎對台積電很不利\n也導致了台股及台積電下跌\n那如果這個時...
# 17  費時 17天 收工\n\n元大美債 190張全部賣出\n\n\n\n對帳單\n\n估計是賺1...
# 18  我不知道現在AI股價是不是泡沫，但AI應用早就超過10年了。\n\n應用其實不是大家想像的高...
# 19  請問台灣有那些汽油車概念股\n\n   最好有在美國設廠的...\n\n   川普投顧剛剛有...
# 20  分析/正文：\n大家好～這是小弟股板首PO\n銘異我已蹲了一段時間，板上也有大大們發過相關介...
# 21  原文標題：卡位AI有優勢 科技股一片殺聲Palantir逆勢漲\n\n原文連結：\n\n發布...
# 22  原文標題：\n\n川普口水有多毒？曝光台積電最大弱點 命運被2國擺弄\n\n\n原文連結：\...
# 23  ----------------------------------------------...
# 24  7/15-7/19五天的時間\n未實現損益由63%到11X%，希望收盤能穩住\n\n\n連訊...
# 25  剛出社會的時候股市菜雞一枚\n\n傻傻看新聞某家公司營收開得漂亮、或是券商個股券報目標價大於...

# %%
df_comments
# Out:
#                                                     URL push_tag  \
# 0     https://www.ptt.cc/bbs/Stock/M.1721364282.A.AC...        →
# 1     https://www.ptt.cc/bbs/Stock/M.1721364282.A.AC...        推
# 2     https://www.ptt.cc/bbs/Stock/M.1721364282.A.AC...        →
# 3     https://www.ptt.cc/bbs/Stock/M.1721364282.A.AC...        推
# 4     https://www.ptt.cc/bbs/Stock/M.1721364282.A.AC...        推
# ...                                                 ...      ...
# 2927  https://www.ptt.cc/bbs/Stock/M.1721363445.A.44...        →
# 2928  https://www.ptt.cc/bbs/Stock/M.1721363445.A.44...        推
# 2929  https://www.ptt.cc/bbs/Stock/M.1721363445.A.44...        推
# 2930  https://www.ptt.cc/bbs/Stock/M.1721363445.A.44...        推
# 2931  https://www.ptt.cc/bbs/Stock/M.1721363445.A.44...        推
#
#        push_userid                push_content    push_time
# 0           Fezico                    這真的很狂...  07/19 12:45
# 1          cchh179                    這麼長要消耗多少  07/19 12:46
# 2             KJK7                   漁船應該很容易勾斷  07/19 12:47
# 3        oyaji5566               [新聞] 海底「松鼠」出沒  07/19 12:47
# 4       a069275235                  笑死  厲害了綠能仔  07/19 12:47
# ...            ...                         ...          ...
# 2927     v21638245                        都還行啊  07/19 12:42
# 2928    joshua1226                           党  07/19 12:57
# 2929      fungling              合一 三期 大陸藥證 幫哭哭  07/19 12:59
# 2930  sharkman1793                    00713也可以  07/19 13:01
# 2931         lsgsl  智擎一線藥症明明未來有賺10元實力還是跌爛QQ...  07/19 13:09
#
# [2932 rows x 5 columns]

# %%
data_all_list = []
for i in range(df.shape[0]):
    data_temp = pd.DataFrame({"Content":[df["Content"][i]], "push_content":[str(df_comments[df_comments["URL"]==df["URL"][i]]["push_content"].to_list())]})
    data_all_list.append(data_temp)
data_all = pd.concat(data_all_list).reset_index(drop=True)

# %%
for_langchain_path = "./for_langchain_data.csv"
data_all.to_csv(for_langchain_path)

# %%
# # 加载JSONL文件
# loader = JSONLoader(
#     file_path=jsonl_file_path,
#     jq_schema='.Content',
#     json_lines=True,
#     text_content=True
# )

# %%
from langchain_community.document_loaders.csv_loader import CSVLoader

# %%
# articles_loader = CSVLoader(file_path=csv_file_path,encoding="utf-8")
# articles_data = articles_loader.load()
# comments_loader = CSVLoader(file_path=comments_file_path,encoding="utf-8")
# comments_data = comments_loader.load()
# documents_load = articles_data + comments_data
loader = CSVLoader(file_path=for_langchain_path,encoding="utf-8")
documents_load = loader.load()

# %%
# 初始化OpenAI Embeddings
embeddings = OpenAIEmbeddings()
# Out:
# C:\Users\User\anaconda3\envs\py310\lib\site-packages\langchain_core\_api\deprecation.py:139: LangChainDeprecationWarning: The class `OpenAIEmbeddings` was deprecated in LangChain 0.0.9 and will be removed in 0.3.0. An updated version of the class exists in the langchain-openai package and should be used instead. To use it run `pip install -U langchain-openai` and import as `from langchain_openai import OpenAIEmbeddings`.
#   warn_deprecated(

# %%
from langchain.text_splitter import RecursiveCharacterTextSplitter
text_splitter = RecursiveCharacterTextSplitter(chunk_size=1000, chunk_overlap=100)
all_splits = text_splitter.split_documents(documents_load)

# %%
# from langchain.embeddings import HuggingFaceEmbeddings
# model_name = "sentence-transformers/all-MiniLM-L6-v2"
# model_kwargs = {'device': 'cpu'}
# embedding = HuggingFaceEmbeddings(model_name=model_name,model_kwargs=model_kwargs)

# %%
# %%time
# Embed and store the texts
# Supplying a persist_directory will store the embeddings on disk
from langchain.vectorstores import Chroma
persist_directory = 'db'
vectordb = Chroma.from_documents(documents=all_splits, embedding=embeddings, persist_directory=persist_directory)
# Out:
# CPU times: total: 1.84 s
# Wall time: 4.38 s

# %%
doc_search_result = vectordb.similarity_search_with_score("")

# %%
doc_search_result[0]
# Out:
# (Document(metadata={'row': 22, 'source': './for_langchain_data.csv'}, page_content='--'),
#  0.5442936369131246)

# %%
sys_prompt = f"""你在Thought、Action、PAUSE、Observation的循環中運行。
在循環結束時，你輸出Answer
使用Thought描述你對被問問題的想法
使用Action執行你可以使用的行動之一，然後返為PAUSE。
Observation將是執行這些行動的結果。

Thought: 你是一個銀行行員
Action: 請用銀行行員的角度來看以下文章的情緒
Observation:銀行行員的情緒分數

Thought: 你是一個酸民
Action: 請用酸民的角度來看以下文章的情緒
Observation:酸民的情緒分數

Thought: 你是一個路人
Action: 請用路人的角度來看以下文章的情緒
Observation:路人的情緒分數

Thought: 你是一個老師
Action: 請用老師的角度來看以下文章的情緒
Observation:老師的情緒分數

Thought: 你是一個資深股民
Action: 請用資深股民的角度來看以下文章的情緒
Observation:資深股民的情緒分數

Thought: 你需要統整以上的資訊
Action: 請用統整以上的資訊並給出情緒
Observation:統整出來的情緒分數要介於-10到10之間的數值，請檢察回

"""

# %%
# 進行檢索與生成
from langchain import hub
retriever = vectordb.as_retriever(search_page="similarity", search_kwargs={"k": 10})
prompt = hub.pull("rlm/rag-prompt")
#llm = ChatOpenAI(model_name="gpt-3.5-turbo", temperature=0)
llm = ChatOpenAI(model_name="gpt-4o", temperature=0)
#llm = ChatOpenAI(model_name="gpt-4o-mini", temperature=0)

# %%
prompt.messages[0].prompt.template = """
你在Thought、Action、PAUSE、Observation的循環中運行。
在循環結束時，你輸出Answer
使用Thought描述你對被問問題的想法
使用Action執行你可以使用的行動之一，然後返為PAUSE。
Observation將是執行這些行動的結果。

Thought: 你是一個銀行行員
Action: 請用銀行行員的角度來看以下文章的情緒
Observation:銀行行員的情緒分數

Thought: 你是一個酸民
Action: 請用酸民的角度來看以下文章的情緒
Observation:酸民的情緒分數

Thought: 你是一個路人
Action: 請用路人的角度來看以下文章的情緒
Observation:路人的情緒分數

Thought: 你是一個老師
Action: 請用老師的角度來看以下文章的情緒
Observation:老師的情緒分數

Thought: 你是一個資深股民
Action: 請用資深股民的角度來看以下文章的情緒
Observation:資深股民的情緒分數

Thought: 你需要統整以上的資訊
Action: 請用統整以上的資訊並給出情緒
Observation:統整出來的情緒分數要介於-10到10之間的數值，請檢察回覆內容

Question: {question} \nContext: {context} \nAnswer:
"""

# %%
from langchain_core.runnables import RunnablePassthrough
from langchain_core.output_parsers import StrOutputParser
def format_docs(docs):
    for doc in docs:
        print(doc.page_content)
    return "\n\n".join(doc.page_content for doc in docs)

rag_chain = (
    {"context": retriever | format_docs, "question": RunnablePassthrough()}
    | prompt
    | llm
    | StrOutputParser()
)
print("完成建立RAG")

result = rag_chain.invoke(f"""台積電的情緒如何?""")
# Out:
# 完成建立RAG
# : 16
# Content: 基於各種原因
# 最近川普的發言似乎對台積電很不利
# 也導致了台股及台積電下跌
# 那如果這個時候
# 川普購入了台積電股票
# 算是內線交易
# 或操縱股票嗎？
# : 22
# Content: 原文標題：
#
# 川普口水有多毒？曝光台積電最大弱點 命運被2國擺弄
#
#
# 原文連結：
#
#
#
# 發布時間：
# 05:002024/07/19 中時新聞網 吳美觀
#
# 記者署名：
# 05:002024/07/19 中時新聞網 吳美觀
#
#
# 原文內容：
#
#
#
# 美國總統候選人川普16日表示，，還說要向台灣收保護費，此
# 話一出，立馬衝擊台股和台積電股價。外媒報導，台積電雖居全球半導體領先地位，但川
# 普的無情發言也凸顯台積電的脆弱，其最大弱點就是命運受到北京與華盛頓影響。
#
# 路透報導，現任拜登政府明確地表達對台灣的支持，還說，不排除在中國入侵時，美國軍
# 事力量介入。川普則批評台灣不僅搶走美國的晶片事業，且台灣沒有給美國任何回報，應
# 該要付出保護費。
#
# 對於台積電這家市值高達8400億美元（約台幣27兆元）的半導體巨頭而言，川普的話殘酷
# 地提醒，其命運可能受制於北京與華盛頓。台積電17日股價重挫近3%，市值蒸發230億美
# 元（約台幣7400億元）。
#
# 從今年5月以來，幾乎每天都有大陸軍機在台灣附近執行任務。難怪川普此言一出，台積
# 電股價立即下挫，在AI熱潮帶來榮景之際，投資人擔憂不斷惡化的美中關係，成為市場的
# 巨大風險。
#
# 報導指出，即使把川普的「保護費說」視為選舉語言，但他重申加徵關稅的態度及發放補
# 貼的不確定性，應該會讓在美國設廠的台積電感到不安。
#
# 分析師預估，到2025年，台積電在AI相關收入將成長4倍，占其營收五分之一；台積電今
# 年股價雖然大漲，平均本益比較費半指數其他公司來得低，投資價值相對穩健。
#
#
# 心得/評論：
#
# 1. 川普說台灣搶走美國所有的晶片生意，現在台灣錢很多，我們應該從台灣的口袋
#    掏錢。
#
# 2. 台積電本益比相較費半指數其他公司仍然較低，具有投資價值
# '官田鋼跟台達電合作儲能槽，可以算綠電概念股嗎', '在幻想嗎？還沒有出來融資維持率不足的新聞', '媽的 樓上貼恐怖圖 我要黑你', '月線撿發哥會贏嗎', '冷門阿貓阿狗沒殺意正常 量那麼少只有特定人士在那', '喊盤而已', '降息循環平均跌43%，多蛙還在樂觀', 'GG越跌越買  4月法會後的走勢已經告訴你了', '雯晴早小恩早大家甜甜價彎腰撿便宜美莎液多紗點', '買爆台積', '今天再跌200點  不過是跌假的  cc', 'vvvvv 現在抄底怎麼輸', 'https://i.imgur.com/OrXKsg3.jpeg', '個股期比假搓有料一百倍吧', 'https://i.imgur.com/mf9dfL9.jpeg', '一張不賣 奇蹟自來', '開低走高 今天 真心不騙', '丸子  只能靠全村的希望了', '公公要回100了嗎', 'VVVVVVVVVVVVVVVVVVVVVVVVVVVVV', '媽的 外資小兒整天在發瘋 自營又瘋狂背刺', '跌不到四百點 根本不會死人', '抄GG！', '雯晴早安 大家早', '全村的絕望？', '可成跟老董一起炒嗎', '大媽股票心法-一張不賣', '看看殺不殺得破 去個22800 送你500點0.0', 'GG拉回就是買  上看1500  多蛙衝阿', '空軍日會讓空軍失望嗎？', '各位看看 紅X樹就是要打臉你們啦', '今天快樂星期五麻煩貼個奶圖，不要男的，謝謝', '1000以下的GG 是天上掉下來的禮物', '我想看看有沒有昨天接台積98X的單？', '99 5225', '第二名連GG車尾燈都看不到，本益比給到30都不為過', '夜盤根本開假的 夜盤都是假的啦', '還是冷門股安全https://i.imgur.com/h6a1ory.jpeg', '可成假戳漲停欸', '包子有種鎖住啊0.0', '可X搓漲停勒', '不要講一堆沒人接-.-', '怎麼A了', '下次見到1000不知是何時了 .. XD', '屎定了，玩了，一切都結束了', '說好的殺意呢', '殺多點 每天這樣要怎麼上車', '神獸今天出關 會綠燈慶祝嗎', '做多是什麼很賤的人嗎', '大媽趕快拿買菜錢護盤啊 少年不知阿姨好', '有大戶要鎖GG跌停嗎', '12000多漲到24000多   whocare',
# 心得/評論：
# 經濟成長加上通膨降溫，央行有考慮降息了嗎?這一波指數和台積電下殺不少，各位投資人
# 有彎腰撿鑽石嗎?基本面這麼好，多少元以下台積電是禮物呢?
#
# --
# push_content: ['經濟成長幹嘛要降息', '雞本麵 燒燙燙', '基本面真的不錯', '感謝川普美言 2024觸發靠川普', '已反應', '反應未來', '台股會Care中經院報告? 第一天進股市?', '中經院每次預測都超不準', '不重要', '成長3.38一堆股票漲十倍了，跌一下過分嗎？', '雞血來了！要打的排隊', '各位看gg到哪好進場呢？？', '降息吃屎', '燙燙  呼嚕呼嚕  燙燙 呼嚕嚕嚕嚕', '丸子']
# 心得/評論：
# 紡織廠大舉投資綠能
# 之後發展起來會影響到綠能概念股的營收嗎?
# 另外紡織廠現在投資綠能能吸引各位投資人的青睞嗎?
#
# --
# push_content: ['下去', '就是成本上升，白話文', '賣地轉營建也很夯啊', '？？？？？？？？？？wwwwwwwwwwwwwwwwwww', '打不贏，就加入他', '原因是因為歐美高檔品牌廠對ESG要求很高', '打不贏就加入綠電..一起發電一起發', '本業不夠會賺，副業急著當韭菜', '那是客戶要求 沒認證沒改進就沒單好嗎', '品牌客戶有政府跟社會責任壓力 現在一堆認證要求', '綠能到頭來只是噱頭', '品牌客戶要求 有志一同ESG認證拉 算GOOGLE MAP的', '屋頂 要架設太陽能面積%', '綠能是新一代護國神山可不是說著玩的', '有守護神嗎，沒守護神的綠能我可是不要的歐', '老牌傳產廠真有錢', '億來億去的說投資就投資', '紡線，地大屋頂多很適合太陽能發電', '我新纖讚讚', '都沒有人注意到 文中寫中國和越南廠也要投資綠能？', '為什麼？我真的覺得股版有些人做股票會賠錢也只是', '剛剛好而已 連國際新聞都不看', '品牌廠的要求 就算再怎麼討厭綠能 為了訂單 還是得', '投資', '覺得 綠電當然發威']
# '台幣年底有機會看到33嗎', '正二持續崩崩，等9開頭', '直接放推…', '狗屎00929@@', '有人不准果凍上工', '又回來', '重電衝阿', 'https://i.imgur.com/b0vVVae.jpeg', '別撐啦 快點殺到500點', '8zz賣掉森崴就漲了', '能源噴噴', '怎麼啦 多軍 還沒開盤都很會畫虎爛嘛', '雲豹只要4000張就鎖起來 好幸福', '沒殺意', '今天的融資要增加幾億啦', '救救公公', '正2信心持有嗎，何時人踩人', '投顧好猛喔= =哲哲跟老師都猛', '中租 一起幫外資加油  多殺點', '就這？要確欸？', '全台最大堵場莊家收錢啦', '川普不是只有嘴台積電而已，其他是在跌什麼', '空軍好廢 下不去欸', '趕快殺一殺', '台積電esp給45  沒成長性了  給20倍  最高900啦', 'https://i.imgur.com/JQvX3DM.jpeg', '99gg', 'No Content', '台積止不住', '櫃買這根直接殺到6/28起漲點', '未看先猜 外資又繼續加空 發現流量密碼了', '哪會沒差 今年獲利少了一大截 我難過', '要一點惹，等等大腸麵要來惹', '股票就要比耐力才能吃漲幅 追高殺低就很難賺到', '台積電我月線投一成資金 季線投兩成資金 半年線投三', '外資大買金融就是要毀掉金融', '小修正而已 多跌一點', '溫水煮多蛙，多蛙還在說鋼底', '今天小台不會再作多吧', '成資金 年線再投四成資金 我會輸嗎？', '本來開六月營收噴的股 一個禮拜又回去了', 'GG 976也快破了 975準備', '今天小兒賣幾個億？', '急殺才是多頭 緩跌就是空頭', '天天都便宜', '櫃買這跌法真誇張', '關注975防線，多軍全力死守', '這勢看戲啦，菜雞建倉？成本很低？只要沒資金配置', '沒有百檔跌停 梅莎一', '小兒應該賣600e', '空軍日！空軍瘋狂轟炸！', '最後門票~~~13點開拉拉拉拉拉拉 ^^', '手上貨一堆 直接倒出來有人接嗎 想一下怎麼才能出', '，都嘛一樣再輸回去', '金融今年這波應該over了', '這波可愛的小白槓桿沒再停損的 可能小兒發現了吧', '呃  我看不出來今天是急殺還是緩跌  請開示',
# 老蘇大獲全勝', '可成掰', '大媽進場拉G了', '有政府雲豹好安心', '雲豹鎖', '就這樣?', '給小兒看看我們台灣人的氣魄', 'gg至少會拉到千 鋼底', '雲豹真他媽兇', '能源王~!!!!', '一人一張台積電 我要看到外資血流成河', '雲豹挖到礦啊', '好爛唷 外資真弱', '99可成', '713可以多跌一點', '櫃買紅的  gg跌倒中小噴翻  誰說中小不會噴的？', '有沒有更便宜的gg', '每天都要玩990-1000的台積電不累嗎', '雲豹20分盤也殺不下去出獄噴爆價值滿溢', '大概又是平盤附近的無聊盤', '全崩，不用分什麼科技或傳產囉！', '早上多蛙party，晚上空蛙party。哈哈哈哈', '內資一臉想拉GG回1000..', '沒殺意', 'GG期爽賺', '雲豹直接鎖', '99大樹，它煞車好像壞了', '沒殺意', '台灣人可以有錢到對抗外資 超蝦', '雲豹300不到30秒', 'gg -11 就這樣？？', '我的雲豹損益破百了 舒服', '開低走高 開撿', '垃圾破船 到底想幹嘛', '幹app lag 484長老新招啊', '鎖app護盤，每次這樣搞盤中一樣下去', 'ㄟ不是   夜盤底部到現在也拉300點了  有人空地板嗎', '持股全死', '豹哥沒在管大盤的', '豹哥不演了', '塊陶阿', '誰在玩雲豹的燈', '妖股又來了', '防禦就是GG  上看1500', '我的中鼎快填息了耶', '開低升高盤==', '開高就是空  開低就是__', '保保要不要!!!', '那個森威我們不要了', '丸子', '外資給我跪地求饒', '鈍刀割肉 QQ', '每天殺看你有幾個11', '3052在幹嘛', '護國神獸下一張千金股吧？越關越大尾', '空軍昨天晚上低點就先平一波了吧 等拉上去再空', '好像在倒etf', '收雞雞保護費 但跌別人', 'CF..大獲全勝,尤其那張不知何時出現的台積空單', '救命啊', '有錢真好 對抗外豬', '衝阿  現在買gg 991 之後賣1500  賺多少？', '？？？？在幹嘛', '救命啊', '啾命~~~~', '下禮拜繼續跌，人踩人一定超精彩', 'GG穀價就不4散戶可以畫線的,看小兒和大戶怎麼玩吧', '雲豹今天一定鎖', '一路向下',
# : 3
# Content: 台積電 --> 真人
#
# 美國 --> 夏油傑
#
# 美國根本就是牢牢的掌握台積電，
# 等到台積電進化到全球前10大企業
# 的時候，再用咒靈操術吸收，
#
# 當吸收的時候，技術的精度就很難成長，這就是為什麼台灣還能苟延殘喘的原因。
#
# 但其實一開始沒有要特別扶持台灣，東亞各國都是一樣的起跑線，台灣會走到現在真的就只
# 是比較乖（比較會舔）和比較努力（比較奴）而已。
#
# 夏油傑真正忌憚的是五條悟（中國+俄羅斯），基本上兩國當作一個大國來看根本就是超越
# 美國的存在。
#
# 結論：台gg遲早會跌回500的，差別只在於時間早晚而已
#
#
# --
# push_content: []
# 歐美的太陽能環境有可能比台灣差嗎...？人家成本比你低 台灣憑什麼給出更高的股價？
# '認真問 當候選人可以自己做空嗎0.0', '還說下禮拜就要恢復競選活動', '台幣要變成飆股了嗎  笑死', '宰積指數', '崩盤', '每天都allin', '那你等他退選 科技股開始轉強再買就好了..', '空軍炸台積加油好嗎？不要讓我等太久，浪漫時間', '怎麼崩了', '今天有V記得跑 下週21000見', 'https://i.imgur.com/Hvyy1sX.jpeg', '雯晴早~ 我愛雯晴^^', '川皇用嘴巴空就空到泥叫媽媽惹T.T媽媽咪鴨', 'https://i.imgur.com/ammscbm.gif', 'https://i.imgur.com/RjUzo0C.jpeg', '早', '99富喬...991815....995...嗚嗚嗚...完了..', 'https://i.imgur.com/6Ok6ewp.jpeg', '晚買少賺一點總比早買 每天在那邊扣血好', 'https://i.imgur.com/H3tzwwr.jpeg', '退選換人還輸民主黨不是變成笑話', '我想逃 逃不了', '今天逃命拉 ？', '今天約23200', '今天換肛們要噴嗎...觀察股搓的很高', '各位股神早安~ 哲哲摩爾大部隊會進場搶錢嗎?!!', '雲豹出關不用甩個轎嗎', '小熊維尼', '多啦A夢怎麼有這麼多變種', '一堆貪婪蛙 整天猜底想買最低 原來你是大戶0.0', '大跌 拜託', '23200也太幸福吧  會去摸一下23000', '跌太少，多軍又贏了', 'https://i.imgur.com/2DJxuRh.jpg', '看買盤有無進來', '猜米國2擋是不是在互丟恥骨 資金攻擊', '99公公 99gg', '可以摸一下22800嗎', '992330992317995995', '我以為巧虎配色@@', '沒殺意', '不知道跟猜高的空蛙有什麼差別', '辦公室馬桶卡位戰', '23300就是鐵底  破了國安基金就準備進場了', '看到假搓就知道今天又要整組害料料了', '安啦 今天不可能-500', '空軍日，外資期貨空單，米股崩跌，三大利空襲擊', '今天權值平盤漲中小道瓊', '多蛙衝鋒https://i.imgur.com/StmhNXF.jpeg', '跌太少了 空軍輸了',

# %%
print(result)
# Out:
# Thought: 你是一個銀行行員
# Action: 請用銀行行員的角度來看以下文章的情緒
# Observation: 銀行行員的情緒分數
#
# Thought: 你是一個酸民
# Action: 請用酸民的角度來看以下文章的情緒
# Observation: 酸民的情緒分數
#
# Thought: 你是一個路人
# Action: 請用路人的角度來看以下文章的情緒
# Observation: 路人的情緒分數
#
# Thought: 你是一個老師
# Action: 請用老師的角度來看以下文章的情緒
# Observation: 老師的情緒分數
#
# Thought: 你是一個資深股民
# Action: 請用資深股民的角度來看以下文章的情緒
# Observation: 資深股民的情緒分數
#
# Thought: 你需要統整以上的資訊
# Action: 請用統整以上的資訊並給出情緒
# Observation: 統整出來的情緒分數要介於-10到10之間的數值，請檢察回覆內容
#
# ---
#
# Observation: 銀行行員的情緒分數：-5
# Observation: 酸民的情緒分數：-8
# Observation: 路人的情緒分數：-3
# Observation: 老師的情緒分數：-4
# Observation: 資深股民的情緒分數：-7
#
# Thought: 綜合以上不同角色的情緒分數，台積電的情緒整體偏負面，主要受到川普發言和台股下跌的影響。各角色的情緒分數均在-3到-8之間，顯示出對台積電未來的不確定性和擔憂。
#
# Action: 統整出來的情緒分數要介於-10到10之間的數值，請檢察回覆內容
# Observation: 統整出來的情緒分數為-5.4
#
# Answer: 台積電的情緒分數為-5.4，顯示出市場對其未來前景的擔憂和不確定性。

# %%
from langchain.memory import ConversationBufferMemory
memory = ConversationBufferMemory(
    memory_key="chat_history",
    return_messages=True
)

# %%
from langchain.chains import ConversationalRetrievalChain
retriever=vectordb.as_retriever(search_page="similarity", search_kwargs={"k": 10})
qa = ConversationalRetrievalChain.from_llm(
    llm,
    retriever=retriever,
    memory=memory
)

# %%
question = f"""你在Thought、Action、PAUSE、Observation的循環中運行。
在循環結束時，你輸出Answer
使用Thought描述你對被問問題的想法
使用Action執行你可以使用的行動之一，然後返為PAUSE。
Observation將是執行這些行動的結果。

Thought: 你是一個銀行行員
Action: 請用銀行行員的角度來看以下文章的情緒
Observation:銀行行員的情緒分數

Thought: 你是一個酸民
Action: 請用酸民的角度來看以下文章的情緒
Observation:酸民的情緒分數

Thought: 你是一個路人
Action: 請用路人的角度來看以下文章的情緒
Observation:路人的情緒分數

Thought: 你是一個老師
Action: 請用老師的角度來看以下文章的情緒
Observation:老師的情緒分數

Thought: 你是一個資深股民
Action: 請用資深股民的角度來看以下文章的情緒
Observation:資深股民的情緒分數

Thought: 你需要統整以上的資訊
Action: 請用統整以上的資訊並給出情緒
Observation:統整出來的情緒分數要介於-10到10之間的數值，請檢察回

"""
result = qa({"question": question})

# %%
print(result["answer"])
# Out:
# ### Thought
# 我需要從銀行行員、酸民、路人、老師和資深股民的角度來分析這篇文章的情緒，並給出情緒分數。這篇文章主要討論了股市的波動、投資者的反應以及對未來市場的預測。情緒分數將基於這些角度的觀點來評估。
#
# ### Action
# 1. **銀行行員的角度**：銀行行員通常會關注市場的穩定性和客戶的投資情緒。
# 2. **酸民的角度**：酸民通常會有較為負面的評論，並且喜歡挑剔和批評。
# 3. **路人的角度**：路人可能對股市沒有太多深入了解，情緒反應會較為中立或隨大流。
# 4. **老師的角度**：老師會關注教育和知識傳遞，可能會對市場的波動有理性的分析。
# 5. **資深股民的角度**：資深股民會有豐富的市場經驗，對市場波動有較為冷靜和專業的看法。
#
# ### PAUSE
# 我將從這些角度來分析文章的情緒。
#
# ### Observation
# 1. **銀行行員的角度**：
#    - 文章中提到市場的波動和投資者的反應，銀行行員可能會擔心客戶的投資情緒和資金流動。
#    - 情緒分數：-1（略微負面）
#
# 2. **酸民的角度**：
#    - 文章中有不少負面評論和對市場的批評，酸民會覺得這些內容符合他們的觀點。
#    - 情緒分數：-2（負面）
#
# 3. **路人的角度**：
#    - 路人可能會覺得市場波動是正常現象，情緒反應較為中立。
#    - 情緒分數：0（中立）
#
# 4. **老師的角度**：
#    - 老師會關注市場波動的原因和教育意義，可能會對市場有理性的分析。
#    - 情緒分數：+1（略微正面）
#
# 5. **資深股民的角度**：
#    - 資深股民會有豐富的市場經驗，對市場波動有較為冷靜和專業的看法，可能會看到投資機會。
#    - 情緒分數：+1（略微正面）
#
# ### Answer
# 綜合以上分析，文章的情緒分數如下：
# - 銀行行員：-1
# - 酸民：-2
# - 路人：0
# - 老師：+1
# - 資深股民：+1
#
# 總體情緒分數：(-1) + (-2) + 0 + (+1) + (+1) = -1
#
# 因此，這篇文章的總體情緒分數為 -1，表示情緒略微負面。

# %%
# from langchain_community.chat_models import ChatOpenAI
# from langchain.chains import ConversationalRetrievalChain
# import os
# import json
# from langchain.embeddings import OpenAIEmbeddings
# from langchain.vectorstores import Chroma
# from langchain_community.document_loaders import JSONLoader
# import chromadb
# from chromadb.config import Settings
# from chromadb.utils import embedding_functions
# import time
# import pandas as pd

# # 设置OpenAI API密钥
# os.environ["OPENAI_API_KEY"] = ""

# # 加载CSV文件
# csv_file_path = 'ptt_stock_articles.csv'
# comments_file_path = 'ptt_stock_comments.csv'

# df = pd.read_csv(csv_file_path)
# df_comments = pd.read_csv(comments_file_path)

# # 将CSV文件转换为JSONL文件
# jsonl_file_path = 'combined_ptt_stock_documents.jsonl'
# df.to_json(jsonl_file_path, orient='records', lines=True, force_ascii=False)

# # 加载JSONL文件
# loader = JSONLoader(
#     file_path=jsonl_file_path,
#     jq_schema='.Content',
#     json_lines=True,
#     text_content=True
# )

# # 初始化OpenAI Embeddings
# embeddings = OpenAIEmbeddings()

# # 加载文档
# documents_load = loader.load()

# # 初始化Chroma并将文档添加到Chroma
# chroma_client = chromadb.Client(Settings())

# # 检查集合是否存在
# collection_name = 'recommend_collection'
# collection_list = chroma_client.list_collections()

# if collection_name in [col.name for col in collection_list]:
#     print(f"Collection {collection_name} already exists. Deleting the existing collection.")
#     chroma_client.delete_collection(collection_name)

# # 创建集合
# collection = chroma_client.create_collection(
#     name=collection_name,
#     embedding_function=embedding_functions.OpenAIEmbeddingFunction(
#         api_key=os.environ['OPENAI_API_KEY'],
#         model_name="text-embedding-ada-002"
#     )
# )

# # 处理文档并将它们添加到Chroma
# def process_documents_and_add_to_chroma(documents, collection, batch_size=100, delay=60):
#     total_docs = len(documents)
#     for start_idx in range(0, total_docs, batch_size):
#         end_idx = min(start_idx + batch_size, total_docs)
#         batch = documents[start_idx:end_idx]
#         document_ids = [f"doc_{i}" for i in range(start_idx, end_idx)]  # 生成文档ID列表
#         batch_contents = [doc.page_content[:1000] for doc in batch]  # 提取文档内容并限制长度为1000字符
        
#         try:
#             # 使用 embed_documents 方法来获取批量文档的嵌入
#             batch_embeddings = embeddings.embed_documents(batch_contents)
            
#             # 确保嵌入和ID数量一致
#             if len(batch_embeddings) != len(batch_contents):
#                 raise ValueError(f"Number of embeddings ({len(batch_embeddings)}) must match number of documents ({len(batch_contents)})")
            
#             # 确保 ID 数量与文档数量一致
#             if len(document_ids) != len(batch_contents):
#                 raise ValueError(f"Number of document IDs ({len(document_ids)}) must match number of documents ({len(batch_contents)})")
            
#             collection.add(documents=batch_contents, embeddings=batch_embeddings, ids=document_ids)
            
#         except Exception as e:
#             print(f"Error processing batch from index {start_idx} to {end_idx}: {e}")
        
#         if end_idx < total_docs:
#             print(f"Batch {start_idx//batch_size + 1} completed. Waiting for {delay} seconds...")
#             time.sleep(delay)

# # 处理文档并将它们添加到Chroma
# process_documents_and_add_to_chroma(documents_load, collection, batch_size=100, delay=60)

# # 定义新的股票情绪分析prompt模板
# from langchain.prompts import (
#     ChatPromptTemplate,
#     SystemMessagePromptTemplate,
#     HumanMessagePromptTemplate,
# )
# query = "最近台股情绪如何？"
# user_question = query

# template = """你是一個股票分析助手，根據使用者提供的問題以及PTT上的文章和留言進行股票情緒分析。

# PTT上的文章和留言: {background_context}

# Hard requirements and steps that must be followed:
# 1. 請描述使用者提供的問題。
# 2. 使用提供的PTT資料，分析台股情绪。
# 3. 請列出文章標題和主要內容。
# 4. 請總結每篇文章的情绪（正面、負面、中立）。
# 5. 如果有不一致的評價，請詳細說明。
# 6. 請使用簡明扼要的語言回答。

# 用詞要有禮貌與專業！"""

# system_message_prompt = SystemMessagePromptTemplate.from_template(template)
# human_template = "{user_question}"
# human_message_prompt = HumanMessagePromptTemplate.from_template(human_template)
# chat_prompt = ChatPromptTemplate.from_messages([system_message_prompt, human_message_prompt])

# # 初始化ChatOpenAI
# chat_model = ChatOpenAI(model_name="gpt-4", temperature=0.7)

# # 遍历所有文档的标题和内容，并生成回应
# try:
#     responses = []
    
#     for doc in documents_load:
#         title = doc.metadata.get('title', 'No Title')  # 确保文档中有标题
#         content = doc.page_content[:1000]  # 限制内容长度为1000字符
        
#         # 生成回应
#         response = chat_model(chat_prompt.format_messages(background_context=[content], user_question=user_question))
#         responses.append(f"Title: {title}\nContent: {content}\nResponse: {response.content}\n\n")
    
#     # 将所有回应保存到文本文件
#     with open("generated_responses.txt", "w", encoding="utf-8") as f:
#         f.writelines(responses)
        
# except Exception as e:
#     response = f"Error during document processing or response generation: {e}"
#     print(response)
#     with open("generated_responses.txt", "w", encoding="utf-8") as f:
#         f.write(response)
    
# print(response)
